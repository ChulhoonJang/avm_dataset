# %%
# date: 17/11/16
# author: chulhoon (chulhoonjang@gmail.com)

# requirements
# - calibration data (rectification parameters, image size)
# - raw avm data

import cv2
import os
import pickle
from tqdm import tqdm

CALIB_PATH = './calib/calib.p'
EXPORT_ROOT = './rectified'

calib = pickle.load(open(CALIB_PATH,"rb"))
t_m = calib["rectified"]
img_size = (int(calib["img_size"][0][0]), int(calib["img_size"][0][1]))

for f in range(2,9):
    folder_name = 'set{}'.format(f)
    
    #make an export directory
    export_path = os.path.join(EXPORT_ROOT, folder_name)
    if os.path.isdir(export_path) == False:
        os.mkdir(export_path)
    
    files = os.listdir(folder_name)
    for i in range(len(files)):
        file = files[i]
        if len(file.split('.')) != 2:
            continue
        if file.split('.')[1] != 'jpg':
            print(file + 'is skipped')
            continue
            
        image_file = os.path.join(folder_name, file)
        image = cv2.imread(image_file)
        
        # crop the top view area
        img_top_view= image[20:459, 13:222, :]
        
        # rectify the top view image
        img_recti = cv2.warpPerspective(img_top_view, t_m, dsize=img_size)
        img_recti = cv2.cvtColor(cv2.flip(cv2.transpose(img_recti),0), cv2.COLOR_BGR2RGB)
        
        # save the rectified image
        save_file = '{:08d}.jpg'.format(int(file.split('_')[-1].split('.')[0]))
        cv2.imwrite(os.path.join(export_path,save_file), img_recti)
# Out:
# RecFile_1_20171108_200319.idxis skipped
# RecFile_1_20171108_200319.idyis skipped
# RecFile_1_20171108_200319.recis skipped
# RecFile_1_20171108_200319_MotionParser_3_speed_x.csvis skipped
# RecFile_1_20171108_200319_MotionParser_3_yaw_rate.csvis skipped
# RecFile_1_20171108_200319_WDM_AnalogVideo_Capture_1_outputIplImage.infis skipped
# RecFile_1_20171108_200419.idxis skipped
# RecFile_1_20171108_200419.idyis skipped
# RecFile_1_20171108_200419.recis skipped
# RecFile_1_20171108_200419_MotionParser_3_speed_x.csvis skipped
# RecFile_1_20171108_200419_MotionParser_3_yaw_rate.csvis skipped
# RecFile_1_20171108_200419_WDM_AnalogVideo_Capture_1_outputIplImage.infis skipped
# RecFile_1_20171108_200515.idxis skipped
# RecFile_1_20171108_200515.idyis skipped
# RecFile_1_20171108_200515.recis skipped
# RecFile_1_20171108_200515_MotionParser_3_speed_x.csvis skipped
# RecFile_1_20171108_200515_MotionParser_3_yaw_rate.csvis skipped
# RecFile_1_20171108_200515_WDM_AnalogVideo_Capture_1_outputIplImage.infis skipped
# RecFile_1_20171108_200606.idxis skipped
# RecFile_1_20171108_200606.idyis skipped
# RecFile_1_20171108_200606.recis skipped
# RecFile_1_20171108_200606_MotionParser_3_speed_x.csvis skipped
# RecFile_1_20171108_200606_MotionParser_3_yaw_rate.csvis skipped
# RecFile_1_20171108_200606_WDM_AnalogVideo_Capture_1_outputIplImage.infis skipped
# RecFile_1_20171108_200654.idxis skipped
# RecFile_1_20171108_200654.idyis skipped
# RecFile_1_20171108_200654.recis skipped
# RecFile_1_20171108_200654_MotionParser_3_speed_x.csvis skipped
# RecFile_1_20171108_200654_MotionParser_3_yaw_rate.csvis skipped
# RecFile_1_20171108_200654_WDM_AnalogVideo_Capture_1_outputIplImage.infis skipped
# RecFile_1_20171108_200740.idxis skipped
# RecFile_1_20171108_200740.idyis skipped
# RecFile_1_20171108_200740.recis skipped
# RecFile_1_20171108_200740_MotionParser_3_speed_x.csvis skipped
# RecFile_1_20171108_200740_MotionParser_3_yaw_rate.csvis skipped
# RecFile_1_20171108_200740_WDM_AnalogVideo_Capture_1_outputIplImage.infis skipped
# RecFile_1_20171108_200827.idxis skipped
# RecFile_1_20171108_200827.idyis skipped
# RecFile_1_20171108_200827.recis skipped
# RecFile_1_20171108_200827_MotionParser_3_speed_x.csvis skipped
# RecFile_1_20171108_200827_MotionParser_3_yaw_rate.csvis skipped
# RecFile_1_20171108_200827_WDM_AnalogVideo_Capture_1_outputIplImage.infis skipped
